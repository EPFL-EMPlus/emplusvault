# %%
# %cd ../..
# %load_ext autoreload
# %autoreload 2

REMOTE_RTS_DATA = "/media/sinergia/RTS/"
REMOTE_VIDEOS = '/mnt/rts/'

LOCAL_RTS_DATA = "/media/data/rts/"
METADATA = LOCAL_RTS_DATA + 'metadata'
LOCAL_VIDEOS = LOCAL_RTS_DATA + 'archive'

OUTDIR = 'data'

HF_TOKEN = "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"
# Out:
# /home/kirell/work/emv

# %%
# LOCAL imports
import emv
import emv.utils
import emv.io.media
import emv.features.audio
import emv.features.text
import emv.features.image

LOG = emv.utils.get_logger()
# Out:
# /home/kirell/.cache/pypoetry/virtualenvs/emv-IgKv7S_O-py3.10/lib/python3.10/site-packages/pydantic/_internal/_fields.py:149: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/kirell/.cache/pypoetry/virtualenvs/emv-IgKv7S_O-py3.10/lib/python3.10/site-packages/pydantic/_internal/_fields.py:149: UserWarning: Field "model_params" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/kirell/.cache/pypoetry/virtualenvs/emv-IgKv7S_O-py3.10/lib/python3.10/site-packages/pydantic/_internal/_config.py:318: UserWarning: Valid config keys have changed in V2:
# * 'orm_mode' has been renamed to 'from_attributes'
#   warnings.warn(message, UserWarning)

# %%
emv.io.media.to_mp3('data/ZB001000_audio.m4a', 'data/ZB001000_audio.mp3')
# Out:
# 'data/ZB001000_audio.mp3'

# %%
res = emv.features.audio.transcribe_media('data/ZB001000_audio.mp3', 'fr', 0, 60)
# Out:
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0. Bad things might happen unless you revert torch to 1.x.
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0. Bad things might happen unless you revert torch to 1.x.

# %%
locs = emv.features.text.find_locations(res)
locs
# Out:
# INFO:RTS:Loading spacy model: fr_core_news_lg
# [{'s': '17.20', 'e': '19.40', 't': "D'accord.", 'sid': 'SPEAKER_11'},
#  {'s': '48.74',
#   'e': '70.53',
#   't': "Les employés romands de Suisse Air sont passés aux actes. Ils ont bloqué plusieurs vols à coin train. Ils refusent de voir leur salaire amputé. Le chauffeur de camion qui a provoqué la tragédie du Gotthard était sous l'emprise de l'alcool. C'est une des révélations de l'enquête. Et puis, des femmes sont descendues dans la rue à Kaboul. Elles demandent plus de droits et plus de liberté.",
#   'sid': 'SPEAKER_09'},
#  {'s': '83.98',
#   'e': '110.93',
# ...
